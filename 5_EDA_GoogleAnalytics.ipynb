# %% [markdown]
# ## Libraries and Data

# %%
#!pip install pytrends

# %%
import pandas as pd
import numpy as np
from pytrends.request import TrendReq

import matplotlib.pylab as plt
# %matplotlib inline

import os 
os.getcwd()
# Out:
# 'C:\\Users\\JIIN\\OneDrive\\Documents\\Github\\2021_Python\\EDA\\EDA_Python'

# %% [markdown]
# ### Data
# - Google Analytics
# - Google Scearch Console
# - Facebook and AdWords

# %%
pd.read_csv('..\\Data\\ga_keyword.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     672         Returns
#     673         -------
# --> 674         bool
#     675
#     676         See Also
#
# ...

# %%
#import Google Analytics Data
kw=pd.read_csv('C:\\Users\\JIIN\\OneDrive\\Documents\\Github\\2021_Python\\EDA\\Data\\ga_keyword.csv', skiprows=6, nrows=5)

# %%
kw
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     672         Returns
#     673         -------
# --> 674         bool
#     675
#     676         See Also
#
# ...
